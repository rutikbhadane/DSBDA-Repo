# %%
import requests
import bs4

# %%
request1= requests.get('https://www.flipkart.com/noise-icon-2-1-8-display-bluetooth-calling-women-s-edition-ai-voice-assistant-smartwatch/p/itm968c523d99eae?pid=SMWGEH7VNGPYN5NV&lid=LSTSMWGEH7VNGPYN5NV83JRUR&marketplace=FLIPKART&store=ajy%2Fbuh&srno=b_1_1&otracker=browse&iid=en_xWcgm1dC79i8TQLd_ACZf7ScorEURb1usolLt1a8wzrO1euMjviTyDNA7NQo4_3SEIcvoFnO9HI4cFS-XMzrgw%3D%3D&ssid=52v6oaplpc0000001714588160711')
request1
# Out:
# <Response [200]>

# %%
request1.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.47c551.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
soup=bs4.BeautifulSoup(request1.text)

# %%
reviews=soup.findAll('div',{'class':'row'});
#<div class="row q4T7rk _8-rIO3"><div class="HO1dRb"><div class="row"><div class="col-4-12"><div class="col"><div class="row"><div class="col-12-12 ggs1+C"><div class="ipqd2A">4.1</div><div class="u12NqW">★</div></div></div><div class="row j-aW8Z"><div class="col-12-12"><span>5,18,399 Ratings &amp;</span></div></div><div class="row j-aW8Z"><div class="col-12-12"><span>33,887 Reviews</span></div></div></div></div><div class="col-8-12 _4b4d6T _6w2YSo"><div class="wNNofW umNoyb "><ul class="lpANVI"><li class="fQ-FC1"><div class="x2IWCo"><span class="Fig8YH">5</span><span class="kDyB8d">★</span></div></li><li class="fQ-FC1"><div class="x2IWCo"><span class="Fig8YH">4</span><span class="kDyB8d">★</span></div></li><li class="fQ-FC1"><div class="x2IWCo"><span class="Fig8YH">3</span><span class="kDyB8d">★</span></div></li><li class="fQ-FC1"><div class="x2IWCo"><span class="Fig8YH">2</span><span class="kDyB8d">★</span></div></li><li class="fQ-FC1"><div class="x2IWCo"><span class="Fig8YH">1</span><span class="kDyB8d">★</span></div></li></ul><ul class="GwkPFK"><li class="fQ-FC1"><div><div class="rsSAZB"><span class="DoUsN7 _3LjBlS" style="width: 100%;"></span></div></div></li><li class="fQ-FC1"><div><div class="rsSAZB"><span class="DoUsN7 CjJqlS" style="width: 34.1012%;"></span></div></div></li><li class="fQ-FC1"><div><div class="rsSAZB"><span class="DoUsN7 +mCBvS" style="width: 13.408%;"></span></div></div></li><li class="fQ-FC1"><div><div class="rsSAZB"><span class="DoUsN7 _9VMLX8" style="width: 6.71843%;"></span></div></div></li><li class="fQ-FC1"><div><div class="rsSAZB"><span class="DoUsN7 SDgpiC" style="width: 17.5772%;"></span></div></div></li></ul><ul class="+psZUR"><li class="fQ-FC1"><div class="BArk-j">3,01,737</div></li><li class="fQ-FC1"><div class="BArk-j">1,02,896</div></li><li class="fQ-FC1"><div class="BArk-j">40,457</div></li><li class="fQ-FC1"><div class="BArk-j">20,272</div></li><li class="fQ-FC1"><div class="BArk-j">53,037</div></li></ul></div></div></div></div><div class="Nwhkb3"><div class="row"><a class="col-3-12 zbCsdp zsSYMX" href="/noise-icon-2-1-8-display-bluetooth-calling-women-s-edition-ai-voice-assistant-smartwatch/product-reviews/itm968c523d99eae?pid=SMWGE
X" href="/noise-icon-2-1-8-display-bluetooth-calling-women-s-edition-ai-voice-assistant-smartwatch/product-reviews/itm968c523d99eae?pid=SMWGEH7VNGPYN5NV&amp;lid=LSTSMWGEH7VNGPYN5NV83JRUR&amp;aid=4df5fe48-c28a-4e89-b941-f9c50b364dea&amp;mid=FLIPKART&amp;fid=afdc38b9-5309-44b1-ae57-b0011c024d8e.SMWGEH7VNGPYN5NV&amp;an=Activity Tracking&amp;cat=Wearable&amp;vert=Smartwatch"><div class="_5nb2hu"><div class="tobygM"><svg class="y5U2lD" viewBox="0 0 100 100"><path class="FhjqaA" d="M50,4 A 46,46,0,1,1,49.9999,4" stroke-width="8" fill-opacity="0"></path><path class="ucl9bG" d="M50,4 A 46,46,0,1,1,4.090770492299505,47.11163610165161" stroke-width="8" fill-opacity="0"></path><text class="_2DdnFS" x="50" y="50">3.8</text></svg></div><div class="NTiEl0">Activity Tracking</div></div></a></div></div></div>
#<div class="OVvZks"><div class="K5lpE5">Ratings &amp; Reviews</div><div class="jvKz74"><button class="QqFHMw YEbu1k" type="submit"><span>Rate Product</span></button></div></div>
for review in reviews:
    print(review.get_text()+ "\n\n")
# Out:
# View 4 more offers
#
#
# DeliveryCheckEnter pincodeDelivery by5 May, Sunday|Free₹40?if ordered before 1:59 AMView Details
#
#
# 4.1★5,18,399 Ratings &33,887 Reviews5★4★3★2★1★3,01,7371,02,89640,45720,27253,0373.7Battery & Charger4.0Display4.1Design3.8Activity Tracking
#
#
# 4.1★5,18,399 Ratings &33,887 Reviews5★4★3★2★1★3,01,7371,02,89640,45720,27253,037
#
#
# 4.1★
#
#
# 5,18,399 Ratings &
#
#
# 33,887 Reviews
#
#
# 3.7Battery & Charger4.0Display4.1Design3.8Activity Tracking
#
#
# + 10098
#
#
# 4Value-for-money
#
#
# I'm in love with thi product thnks filpkart for thi worth❤️😊READ MORE
#
#
# Khushi SinghCertified Buyer, AgraDec, 20222473573PermalinkReport Abuse
#
#
# Khushi SinghCertified Buyer, AgraDec, 2022
#
#
# 2473573PermalinkReport Abuse
#
#
# 4Pretty good
#
#
# Good lookingREAD MORE
#
#
# Rakesh  KarmakarCertified Buyer, Nadia DistrictJul, 2022672144PermalinkReport Abuse
#
#
# Rakesh  KarmakarCertified Buyer, Nadia DistrictJul, 2022
#
#
# 672144PermalinkReport Abuse
#
#
# ...

# %%
ratings=soup.find('div',{'class': 'col-4-12'})
print(ratings.get_text())
# Out:
# 4.1★5,18,399 Ratings &33,887 Reviews

# %%
individual_ratings=soup.findAll('div'=={'class' :'vim x-review-section'});
for indi_rating in individual_ratings:
    print(indi_rating.get_text()+"\n\n")

#<li class="vim x-review-section" id="review_10000000305048255" data-testid="x-review-section"><div class="x-review-section__l"><div class="x-review-section__star--rating"><div class="vim ux-star-rating" data-testid="ux-star-rating"><div role="img" aria-label="percents of reviewers think of this product as" class="star-rating" data-stars="4-0"><svg class="star-rating__icon icon icon--star-dynamic" focusable="false" aria-hidden="true"><use href="#icon-star-dynamic"></use></svg><svg class="star-rating__icon icon icon--star-dynamic" focusable="false" aria-hidden="true"><use href="#icon-star-dynamic"></use></svg><svg class="star-rating__icon icon icon--star-dynamic" focusable="false" aria-hidden="true"><use href="#icon-star-dynamic"></use></svg><svg class="star-rating__icon icon icon--star-dynamic" focusable="false" aria-hidden="true"><use href="#icon-star-dynamic"></use></svg><svg class="star-rating__icon icon icon--star-dynamic" focusable="false" aria-hidden="true"><use href="#icon-star-dynamic"></use></svg></div></div></div><div class="x-review-section__author"><span class="ux-textspans"> by </span><a href="https://www.ebay.com/usr/flatlander52-ew" class="ux-action" data-testid="ux-action" _sp="p4429486.m3946.l7022" data-vi-tracking="{&quot;eventFamily&quot;:&quot;ITM&quot;,&quot;eventAction&quot;:&quot;ACTN&quot;,&quot;actionKind&quot;:&quot;CLICK&quot;,&quot;operationId&quot;:&quot;4429486&quot;,&quot;flushImmediately&quot;:false,&quot;eventProperty&quot;:{&quot;parentrq&quot;:&quot;355efaaf18f0adb93b0fb1a6fffc31cf&quot;,&quot;pageci&quot;:&quot;42ff3a52-f764-402f-bc07-e4d21e177a1d&quot;,&quot;moduledtl&quot;:&quot;mi:3946|li:7022&quot;,&quot;sid&quot;:&quot;p4429486.m3946.l7022&quot;}}" data-click="{&quot;eventFamily&quot;:&quot;ITM&quot;,&quot;eventAction&quot;:&quot;ACTN&quot;,&quot;actionKind&quot;:&quot;CLICK&quot;,&quot;operationId&quot;:&quot;4429486&quot;,&quot;flushImmediately&quot;:false,&quot;eventProperty&quot;:{&quot;parentrq&quot;:&quot;355efaaf18f0adb93b0fb1a6fffc31cf&quot;,&quot;pageci&quot;:&quot;42ff3a52-f764-402f-bc07-e4d21e177a1d&quot;,&quot;moduledtl&quot;:&quot;mi:3946|li:7022&quot;,&quot;sid&quot;:&quot;p4429486.m3946.l7022&quot;}}"><span class="ux-textspans">flatlander52-ew</span></a></div><span class="x-review-section__date"><span class="ux-textspans">Jan 30, 2022</span></span></div><div class="x-review-section__r"><h4 class="x-review-section__title">Very good product yet a potential buyer needs to research its' capabilities first.</h4><div class="x-review-section__content"><span class="ux-expandable-textual-display-block-inline"><span data-testid="text"><span class="ux-textspans">This item was purchased for a specific purpose/function. That is the ability to record hands free while moving around. Image quality is excellent. A prospective buyer needs to clearly understand what the unit can do well and where it does have some limitations. If one intends to use it to film continuously for an hour or so - it may not be what you want. All in all, a very good unit and for my uses- an excellent choice. </span></span></span><span aria-hidden="true" class="ux-expandable-textual-display-block-inline hide" data-testid="ux-expandable-textual-display-block-inline"><span data-testid="text"><span class="ux-textspans">This item was purchased for a specific purpose/function. That is the ability to record hands free while moving around. Image quality is excellent. A prospective buyer needs to clearly understand what the unit can do well and where it does have some limitations. If one intends to use it to film continuously for an hour or so - it may not be what you want. All in all, a very good unit and for my uses- an excellent choice. </span></span> </span></div><p class="x-review-section__attr"><span><span class="ux-textspans">Verified purchase: Yes</span></span><span><span class="ux-textspans">Condition: Pre-Owned</span></span><span><span class="ux-textspans">Sold by: pikapikachu4me</span></span></p></div></li>
# Out:
#  Noise Icon 2 1.8'' Display with Bluetooth Calling, Women's Edition, AI Voice Assistant Smartwatch Price in India - Buy Noise Icon 2 1.8'' Display with Bluetooth Calling, Women's Edition, AI Voice Assistant Smartwatch online at Flipkart.com      Explore PlusLoginBecome a Seller More Cart Add to cart Buy NowBig Saving Days Starts in12 hrs : 00 mins : 02 secsHomeWearable Smart DevicesSmart WatchesNoise Smart WatchesNoise Icon 2 1.8'' Display with Bluetooth Calling, Women's Edition, AI Voice Assistant Smartwatch (Pink Strap, Regular)
# ...

# %%
tags=soup.find('span'== {'class' :'yhB1nd GXgmTe'}).get_text();
tags
# Out:
# ' Noise Icon 2 1.8\'\' Display with Bluetooth Calling, Women\'s Edition, AI Voice Assistant Smartwatch Price in India - Buy Noise Icon 2 1.8\'\' Display with Bluetooth Calling, Women\'s Edition, AI Voice Assistant Smartwatch online at Flipkart.com      Explore PlusLoginBecome a Seller More Cart Add to cart Buy NowBig Saving Days Starts in12 hrs : 00 mins : 02 secsHomeWearable Smart DevicesSmart WatchesNoise Smart WatchesNoise Icon 2 1.8\'\' Display with Bluetooth Calling, Women\'s Edition, AI Voice Assistant Smartwatch (Pink Strap, Regular)\nCompareShareNoise Icon 2 1.8\'\' Display with Bluetooth Calling, Women\'s Edition, AI Voice Assistant Smartwatch\xa0\xa0(Pink Strap, Regular)#JustHere4.15,18,399 Ratings\xa0&\xa033,887 ReviewsSpecial price₹1,299₹5,99978% offiAvailable offersBank Offer5% Cashback on Flipkart Axis Bank CardT&CBank OfferExtra ₹500 off on SBI Credit Card and EMI Transactions, on a Net Cart Value of ₹24,990 and aboveT&CBank OfferExtra ₹500 off on SBI Credit Card and E
# ...

# %%
customer_name= soup.findAll('p' , { 'class' : '_2sc7ZR _2V5EHH'});
for cust in customer_name:
    print(cust.get_text() + "\n\n")

# %%
price= soup.find('div'== {'class' : '_30jeq3 _16Jk6d'}).get_text();
print(price)
# Out:
#  MOTOROLA Edge 40 Neo ( 128 GB Storage, 8 GB RAM ) Online at Best Price On Flipkart.com      Explore PlusLoginBecome a Seller More Cart Add to cart Buy NowBig Saving Days Starts in22 hrs : 50 mins : 28 secsHomeMobiles & AccessoriesMobilesMOTOROLA MobilesMotorola Edge 40 Neo (Black Beauty, 128 GB) (8 GB RAM)
# ...

# %%
spe = soup.find_all('td'== {'class' : '_1hKmbr'});
for s in spe:
    print(s.get_text())
    ans= s.findNext('td'== {'class' : 'URwL2w'}).get_text();
    print(ans)
# Out:
#  Noise Icon 2 1.8'' Display with Bluetooth Calling, Women's Edition, AI Voice Assistant Smartwatch Price in India - Buy Noise Icon 2 1.8'' Display with Bluetooth Calling, Women's Edition, AI Voice Assistant Smartwatch online at Flipkart.com      Explore PlusLoginBecome a Seller More Cart Add to cart Buy NowBig Saving Days Starts in12 hrs : 00 mins : 02 secsHomeWearable Smart DevicesSmart WatchesNoise Smart WatchesNoise Icon 2 1.8'' Display with Bluetooth Calling, Women's Edition, AI Voice Assistant Smartwatch (Pink Strap, Regular)
# ...
