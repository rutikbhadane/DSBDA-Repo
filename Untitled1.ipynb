# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns

# %%
df = pd.read_csv("AirQuality.csv",sep = ";")

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %%
# calculating null values
df.isna().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
# dropping columns with 100% null values

df = df.drop(["Unnamed: 15"],axis=1)
df = df.drop(["Unnamed: 16"],axis=1)

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)            object
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)          object
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                 object
# RH                object
# AH                object
# dtype: object

# %%
df["PT08.S1(CO)"].fillna(df["PT08.S1(CO)"].mode(),inplace=True)
df["NMHC(GT)"].fillna(df["NMHC(GT)"].median(),inplace=True)
df["PT08.S2(NMHC)"].fillna(df["PT08.S2(NMHC)"].median(),inplace=True)
df["NOx(GT)"].fillna(df["NOx(GT)"].mean(),inplace=True)
df["PT08.S3(NOx)"].fillna(df["PT08.S3(NOx)"].median(),inplace=True)
df["NO2(GT)"].fillna(df["NO2(GT)"].mean(),inplace=True)
df["PT08.S4(NO2)"].fillna(df["PT08.S4(NO2)"].median(),inplace=True)
df["PT08.S5(O3)"].fillna(df["PT08.S5(O3)"].median(),inplace=True)

# %%
df["CO(GT)"].fillna(df["CO(GT)"].ffill(),inplace=True)

# %%
df["T"] = df["T"].ffill()

# %%
df["RH"]  = df["RH"].ffill()

# %%
df["AH"]  = df["AH"].ffill()

# %%
df["Time"]  = df["Time"].ffill()

# %%
df["Date"]  = df["Date"].ffill()

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)    NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6  1360.000000  150.000000     11,9
# 1     10/03/2004  19.00.00      2  1292.000000  112.000000      9,4
# 2     10/03/2004  20.00.00    2,2  1402.000000   88.000000      9,0
# 3     10/03/2004  21.00.00    2,2  1376.000000   80.000000      9,2
# 4     10/03/2004  22.00.00    1,6  1272.000000   51.000000      6,5
# ...          ...       ...    ...          ...         ...      ...
# 9466  04/04/2005  14.00.00    2,2  1048.990061 -159.090093      NaN
# 9467  04/04/2005  14.00.00    2,2  1048.990061 -159.090093      NaN
# 9468  04/04/2005  14.00.00    2,2  1048.990061 -159.090093      NaN
# 9469  04/04/2005  14.00.00    2,2  1048.990061 -159.090093      NaN
# 9470  04/04/2005  14.00.00    2,2  1048.990061 -159.090093      NaN
#
#       PT08.S2(NMHC)     NOx(GT)  PT08.S3(NOx)     NO2(GT)  PT08.S4(NO2)  \
# 0       1046.000000  166.000000   1056.000000  113.000000   1692.000000
# ...

# %%
df2 = pd.read_csv("heart (1).csv")

# %%
df2
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df2.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
pd.get_dummies(df2)
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  \
# ...

# %%
df2.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df2['Sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df2['RestingECG'].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df2['HeartDisease'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df2['FastingBS'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df2['RestingECG'].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df2['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df2['ExerciseAngina'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df2['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df2['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
df2.groupby("Cholesterol")['HeartDisease'].sum()
# Out:
# Cholesterol
# 0      152
# 85       0
# 100      1
# 110      1
# 113      1
#       ...
# 491      1
# 518      1
# 529      1
# 564      0
# 603      1
# Name: HeartDisease, Length: 222, dtype: int64

# %%
#df2.groupby("Cholesterol").sum()

# %%
import matplotlib.pyplot as plt
plt.bar(df2["ChestPainType"].unique(),df2['ChestPainType'].value_counts())
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.pie(df2['ChestPainType'].value_counts(),labels=(df2["ChestPainType"].unique()))
plt.legend(df2['ChestPainType'].value_counts())
plt.title("Types of Chestpain")
# Out:
# Text(0.5, 1.0, 'Types of Chestpain')

# %%
df.sample(10)
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 3259  24/07/2004  13.00.00    1,2       1058.0    -200.0      6,5
# 1984  01/06/2004  10.00.00    1,8       1182.0    -200.0     12,0
# 365   25/03/2004  23.00.00    1,2        979.0      67.0      4,5
# 3205  22/07/2004  07.00.00    4,4       1518.0    -200.0     26,9
# 2467  21/06/2004  13.00.00    1,2        838.0    -200.0      7,2
# 6325  29/11/2004  07.00.00      2       1129.0    -200.0      9,8
# 4525  15/09/2004  07.00.00   -200       1298.0    -200.0     16,1
# 3946  22/08/2004  04.00.00   -200        843.0    -200.0      4,0
# 8773  11/03/2005  07.00.00    0,2        987.0    -200.0      4,5
# 1637  17/05/2004  23.00.00    1,3       1003.0    -200.0      7,4
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 3259          833.0     47.0         804.0     53.0        1623.0
# 1984         1051.0    211.0         829.0     89.0        1870.0
# ...

# %%
sns.pairplot(df.drop(columns=["Date","Time"]))

# %%
df.describe().T
# Out:
#                 count         mean         std    min     25%          50%  \
# PT08.S1(CO)    9471.0  1048.990061  327.841433 -200.0   923.0  1050.000000
# NMHC(GT)       9471.0  -159.090093  138.945154 -200.0  -200.0  -200.000000
# PT08.S2(NMHC)  9471.0   894.595276  340.266507 -200.0   713.0   894.595276
# NOx(GT)        9471.0   168.616971  255.879678 -200.0    51.0   144.000000
# PT08.S3(NOx)   9471.0   794.990168  320.049602 -200.0   639.0   794.990168
# NO2(GT)        9471.0    58.148873  126.174086 -200.0    54.0    95.000000
# PT08.S4(NO2)   9471.0  1391.479641  464.389469 -200.0  1189.0  1440.000000
# PT08.S5(O3)    9471.0   975.072032  454.179543 -200.0   703.0   949.000000
#
#                   75%     max
# PT08.S1(CO)    1218.0  2040.0
# NMHC(GT)       -200.0  1189.0
# PT08.S2(NMHC)  1102.0  2214.0
# NOx(GT)         281.5  1479.0
# PT08.S3(NOx)    957.0  2683.0
# NO2(GT)         132.0   340.0
# PT08.S4(NO2)   1658.0  2775.0
# PT08.S5(O3)    1250.0  2523.0
